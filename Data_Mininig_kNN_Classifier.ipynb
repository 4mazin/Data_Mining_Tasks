# %%
import pandas as pd
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\Data Analysis_Bootcamp\Data Mining Project\car_evaluation_with_missing_values.csv" , header = None)
df
# Out:
#           0        1      2     3      4     5      6
# 0     vhigh  vhigh.1      2   2.1  small   low  unacc
# 1     vhigh    vhigh      2     2  small   med  unacc
# 2     vhigh    vhigh      2     2  small  high  unacc
# 3       NaN    vhigh      2     2    med   NaN  unacc
# 4     vhigh    vhigh      2     2    med   med  unacc
# ...     ...      ...    ...   ...    ...   ...    ...
# 1723    low      low  5more  more    med   med   good
# 1724    low      low  5more  more    med  high  vgood
# 1725    low      low  5more  more    big   low  unacc
# 1726    low      low  5more  more    big   med   good
# 1727    low      low  5more  more    big   NaN  vgood
#
# [1728 rows x 7 columns]

# %%
# Dropping first row
df = df.drop(index=0)
df
# Out:
#           0      1      2     3      4     5      6
# 1     vhigh  vhigh      2     2  small   med  unacc
# 2     vhigh  vhigh      2     2  small  high  unacc
# 3       NaN  vhigh      2     2    med   NaN  unacc
# 4     vhigh  vhigh      2     2    med   med  unacc
# 5     vhigh  vhigh      2   NaN    med   NaN  unacc
# ...     ...    ...    ...   ...    ...   ...    ...
# 1723    low    low  5more  more    med   med   good
# 1724    low    low  5more  more    med  high  vgood
# 1725    low    low  5more  more    big   low  unacc
# 1726    low    low  5more  more    big   med   good
# 1727    low    low  5more  more    big   NaN  vgood
#
# [1727 rows x 7 columns]

# %%
# Adding headers to the dataset
new_headers = ['buying_price' , 'maitenance_cost' , 'num_of_doors' , 'num_of_persons' , 'lug_boot' , 'safety' , 'Decision']
df.columns = new_headers
df.head()
# Out:
#   buying_price maitenance_cost num_of_doors num_of_persons lug_boot safety  \
# 1        vhigh           vhigh            2              2    small    med
# 2        vhigh           vhigh            2              2    small   high
# 3          NaN           vhigh            2              2      med    NaN
# 4        vhigh           vhigh            2              2      med    med
# 5        vhigh           vhigh            2            NaN      med    NaN
#
#   Decision
# 1    unacc
# 2    unacc
# 3    unacc
# 4    unacc
# 5    unacc

# %%
# Chicking Data Types Of The Columns
print(df.dtypes)
# Out:
# buying_price       object
# maitenance_cost    object
# num_of_doors       object
# num_of_persons     object
# lug_boot           object
# safety             object
# Decision           object
# dtype: object

# %%
# Removing Duplicate values
df.drop_duplicates()
df.describe()
# Out:
#        buying_price maitenance_cost num_of_doors num_of_persons lug_boot  \
# count          1557            1554         1564           1542     1554
# unique            4               4            4              3        3
# top            high           vhigh        5more              2      big
# freq            398             391          396            519      526
#
#        safety Decision
# count    1562     1548
# unique      3        4
# top       med    unacc
# freq      527     1077

# %%
# Chicking If There Is Any Missing Values
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# buying_price       170
# maitenance_cost    173
# num_of_doors       163
# num_of_persons     185
# lug_boot           173
# safety             165
# Decision           179
# dtype: int64

# %%
df
# Out:
#      buying_price maitenance_cost num_of_doors num_of_persons lug_boot safety  \
# 1           vhigh           vhigh            2              2    small    med
# 2           vhigh           vhigh            2              2    small   high
# 3             NaN           vhigh            2              2      med    NaN
# 4           vhigh           vhigh            2              2      med    med
# 5           vhigh           vhigh            2            NaN      med    NaN
# ...           ...             ...          ...            ...      ...    ...
# 1723          low             low        5more           more      med    med
# 1724          low             low        5more           more      med   high
# 1725          low             low        5more           more      big    low
# 1726          low             low        5more           more      big    med
# 1727          low             low        5more           more      big    NaN
#
#      Decision
# 1       unacc
# 2       unacc
# 3       unacc
# 4       unacc
# 5       unacc
# ...       ...
# 1723     good
# 1724    vgood
# 1725    unacc
# 1726     good
# 1727    vgood
#
# [1727 rows x 7 columns]

# %%
# Handling with missing values with (MODE) Techneque for categorical columns
most_frequent = df['buying_price'].mode()[0]
df['buying_price']  =df['buying_price'].fillna(most_frequent)
df['buying_price']
# Out:
# 1       vhigh
# 2       vhigh
# 3        high
# 4       vhigh
# 5       vhigh
#         ...
# 1723      low
# 1724      low
# 1725      low
# 1726      low
# 1727      low
# Name: buying_price, Length: 1727, dtype: object

# %%
most_frequent = df['maitenance_cost'].mode()[0]
df['maitenance_cost']  =df['maitenance_cost'].fillna(most_frequent)
df['maitenance_cost']
# Out:
# 1       vhigh
# 2       vhigh
# 3       vhigh
# 4       vhigh
# 5       vhigh
#         ...
# 1723      low
# 1724      low
# 1725      low
# 1726      low
# 1727      low
# Name: maitenance_cost, Length: 1727, dtype: object

# %%
most_frequent = df['lug_boot'].mode()[0]
df['lug_boot']  =df['lug_boot'].fillna(most_frequent)
df['lug_boot']
# Out:
# 1       small
# 2       small
# 3         med
# 4         med
# 5         med
#         ...
# 1723      med
# 1724      med
# 1725      big
# 1726      big
# 1727      big
# Name: lug_boot, Length: 1727, dtype: object

# %%
most_frequent = df['safety'].mode()[0]
df['safety']  =df['safety'].fillna(most_frequent)
df['safety']
# Out:
# 1        med
# 2       high
# 3        med
# 4        med
# 5        med
#         ...
# 1723     med
# 1724    high
# 1725     low
# 1726     med
# 1727     med
# Name: safety, Length: 1727, dtype: object

# %%
most_frequent = df['Decision'].mode()[0]
df['Decision']  =df['Decision'].fillna(most_frequent)
df['Decision']
# Out:
# 1       unacc
# 2       unacc
# 3       unacc
# 4       unacc
# 5       unacc
#         ...
# 1723     good
# 1724    vgood
# 1725    unacc
# 1726     good
# 1727    vgood
# Name: Decision, Length: 1727, dtype: object

# %%
# Chicking If There Is Any Missing Values
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# buying_price         0
# maitenance_cost      0
# num_of_doors       163
# num_of_persons     185
# lug_boot             0
# safety               0
# Decision             0
# dtype: int64

# %%
df['num_of_doors'] = df['num_of_doors'].replace('5more', 5)
df['num_of_persons'] = df['num_of_persons'].replace('more', 5)

# %%
# Dealing with numeric values with (mean techneque)
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
df[['num_of_doors', 'num_of_persons']] = imputer.fit_transform(df[['num_of_doors', 'num_of_persons']])
df
# Out:
#      buying_price maitenance_cost  num_of_doors  num_of_persons lug_boot  \
# 1           vhigh           vhigh           2.0        2.000000    small
# 2           vhigh           vhigh           2.0        2.000000    small
# 3            high           vhigh           2.0        2.000000      med
# 4           vhigh           vhigh           2.0        2.000000      med
# 5           vhigh           vhigh           2.0        3.659533      med
# ...           ...             ...           ...             ...      ...
# 1723          low             low           5.0        5.000000      med
# 1724          low             low           5.0        5.000000      med
# 1725          low             low           5.0        5.000000      big
# 1726          low             low           5.0        5.000000      big
# 1727          low             low           5.0        5.000000      big
#
#      safety Decision
# 1       med    unacc
# 2      high    unacc
# 3       med    unacc
# 4       med    unacc
# 5       med    unacc
# ...     ...      ...
# 1723    med     good
# 1724   high    vgood
# 1725    low    unacc
# 1726    med     good
# 1727    med    vgood
#
# [1727 rows x 7 columns]

# %%
df['num_of_doors'] = df['num_of_doors'].astype(int)
df['num_of_persons'] = df['num_of_persons'].astype(int)
df
# Out:
#      buying_price maitenance_cost  num_of_doors  num_of_persons lug_boot  \
# 1           vhigh           vhigh             2               2    small
# 2           vhigh           vhigh             2               2    small
# 3            high           vhigh             2               2      med
# 4           vhigh           vhigh             2               2      med
# 5           vhigh           vhigh             2               3      med
# ...           ...             ...           ...             ...      ...
# 1723          low             low             5               5      med
# 1724          low             low             5               5      med
# 1725          low             low             5               5      big
# 1726          low             low             5               5      big
# 1727          low             low             5               5      big
#
#      safety Decision
# 1       med    unacc
# 2      high    unacc
# 3       med    unacc
# 4       med    unacc
# 5       med    unacc
# ...     ...      ...
# 1723    med     good
# 1724   high    vgood
# 1725    low    unacc
# 1726    med     good
# 1727    med    vgood
#
# [1727 rows x 7 columns]

# %%
# Missing values handeled :)

# %%
# Chickung the data if balance or imbalance

class_count = df['buying_price'].value_counts()
print(class_count)
print('-------------------------------------')

class_count = df['maitenance_cost'].value_counts()
print(class_count)
print('-------------------------------------')

class_count = df['num_of_doors'].value_counts()
print(class_count)
print('-------------------------------------')

class_count = df['num_of_persons'].value_counts()
print(class_count)
print('-------------------------------------')

class_count = df['lug_boot'].value_counts()
print(class_count)
print('-------------------------------------')

class_count = df['safety'].value_counts()
print(class_count)
print('-------------------------------------')

class_count = df['Decision'].value_counts()
print(class_count)
print('-------------------------------------')
# Out:
# buying_price
# high     568
# med      388
# vhigh    387
# low      384
# Name: count, dtype: int64
# -------------------------------------
# maitenance_cost
# vhigh    564
# high     390
# low      390
# med      383
# Name: count, dtype: int64
# -------------------------------------
# num_of_doors
# 3    557
# 5    396
# 4    390
# 2    384
# Name: count, dtype: int64
# -------------------------------------
# num_of_persons
# 2    519
# 5    513
# 4    510
# 3    185
# Name: count, dtype: int64
# -------------------------------------
# lug_boot
# big      699
# med      517
# small    511
# Name: count, dtype: int64
# -------------------------------------
# safety
# med     692
# low     520
# high    515
# Name: count, dtype: int64
# -------------------------------------
# Decision
# unacc    1256
# acc       350
# vgood      61
# good       60
# Name: count, dtype: int64
# -------------------------------------

# %%
# Under sampling Decision column
from sklearn.utils import resample

#classes count
count_class_unacc, count_class_acc , count_clas_vgood , count_class_good = df.Decision.value_counts()

# divide the data by class
df_class_unacc = df[df['Decision'] == 'unacc']
df_clas_acc = df[df['Decision'] == 'acc']
df_class_vgood = df[df['Decision'] == 'vgood']
df_class_good = df[df['Decision'] == 'good']

# Find the size of the smallest class (here, the minority classes)
min_class_size = min(len(df_clas_acc), len(df_class_vgood), len(df_class_good))

# Perform under-sampling by randomly selecting the same number of samples from the majority class
df_class_unacc = df_class_unacc.sample(n=min_class_size, random_state=42)

if len(df_clas_acc) > min_class_size:
    df_clas_acc = df_clas_acc.sample(n=min_class_size, random_state=42)

# Combine all the classes back into a balanced dataset
df_balanced = pd.concat([df_class_unacc, df_clas_acc, df_class_vgood, df_class_good])

# Shuffle the data to avoid any order bias
df_balanced = df_balanced.sample(frac=1, random_state=42).reset_index(drop=True)

df_balanced.Decision.value_counts().plot(kind = 'bar' , title = 'undersampling')
# Out:
# <Axes: title={'center': 'undersampling'}, xlabel='Decision'>

# %%
# Over Sampling numr_of_persons

# Divide the data by class
df_class_2 = df[df['num_of_persons'] == 2]
df_class_5 = df[df['num_of_persons'] == 5]
df_class_4 = df[df['num_of_persons'] == 4]
df_class_3 = df[df['num_of_persons'] == 3]

# Find the size of the largest class (target size for over-sampling)
max_class_size = max(len(df_class_2), len(df_class_5), len(df_class_4))

# Perform over-sampling for the '3' class
df_class_3 = df_class_3.sample(n=max_class_size, replace=True, random_state=42)

# Combine all the classes back into a balanced dataset
df_balanced = pd.concat([df_class_2, df_class_5, df_class_4, df_class_3])

# Shuffle the data to avoid any order bias
df_balanced = df_balanced.sample(frac=1, random_state=42).reset_index(drop=True)

# Plot the class distribution after over-sampling
df_balanced['num_of_persons'].value_counts().plot(kind='bar', title='Over-sampling: Balanced Classes')
# Out:
# <Axes: title={'center': 'Over-sampling: Balanced Classes'}, xlabel='num_of_persons'>

# %%
df.head()
# Out:
#   buying_price maitenance_cost  num_of_doors  num_of_persons lug_boot safety  \
# 1        vhigh           vhigh             2               2    small    med
# 2        vhigh           vhigh             2               2    small   high
# 3         high           vhigh             2               2      med    med
# 4        vhigh           vhigh             2               2      med    med
# 5        vhigh           vhigh             2               3      med    med
#
#   Decision
# 1    unacc
# 2    unacc
# 3    unacc
# 4    unacc
# 5    unacc

# %%
# encode columns
from sklearn.preprocessing import LabelEncoder

categorical_columns = ['buying_price', 'maitenance_cost', 'lug_boot', 'safety']

# Create a dictionary to store encoders for each column (useful for inverse transformation later)
label_encoders = {}
for col in categorical_columns:
    le = LabelEncoder()  # Initialize a LabelEncoder
    df[col] = le.fit_transform(df[col])  # Fit and transform the column
    label_encoders[col] = le  # Store the encoder for future use
print(df.head())
# Out:
#    buying_price  maitenance_cost  num_of_doors  num_of_persons  lug_boot  \
# 1             3                3             2               2         2
# 2             3                3             2               2         2
# 3             0                3             2               2         1
# 4             3                3             2               2         1
# 5             3                3             2               3         1
#
#    safety Decision
# 1       2    unacc
# 2       0    unacc
# 3       2    unacc
# 4       2    unacc
# 5       2    unacc

# %%
# now Data is ready for kNN classifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score

# %%
input = df[['buying_price', 'maitenance_cost', 'num_of_doors', 'num_of_persons', 'lug_boot' , 'safety']]
output = df['Decision']

# Select predictors and target
input = df[['buying_price', 'maitenance_cost', 'num_of_doors', 'num_of_persons', 'lug_boot' , 'safety']]
output = df['Decision']

# Split the dataset into training and testing sets
input_train, input_test, output_train, output_test = train_test_split(input, output, test_size=0.2, random_state=None)

# Initialize and train the KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(input_train, output_train)

# Make predictions
output_pred = knn.predict(input_test)

# Evaluate the model
accuracy = accuracy_score(output_test, output_pred)
print(accuracy)
# Out:
# 0.8208092485549133

# %%
# Making Confution Matrix and heatmap

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Create confusion matrix
cm = confusion_matrix(output_test, output_pred)
print(cm)
# Out:
# [[ 45   1  24   1]
#  [  4   3   4   0]
#  [ 19   1 234   1]
#  [  1   2   4   2]]

# %%
sns.heatmap(cm, annot=True, fmt="d", cmap="Reds", xticklabels=['unacc', 'acc', 'vgood' , 'good'], yticklabels=['unacc', 'acc', 'vgood' , 'good'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
class_count = df['Decision'].value_counts()
print(class_count)
print('-------------------------------------')
# Out:
# Decision
# unacc    1256
# acc       350
# vgood      61
# good       60
# Name: count, dtype: int64
# -------------------------------------

# %%
import matplotlib.pyplot as plt
print(plt.colormaps())
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'grey', 'gist_grey', 'gist_yerg', 'Grays', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'Blues_r', 'BrBG_r', 'BuGn_r', 'BuPu_r', 'CMRmap_r', 'GnBu_r', 'Greens_r', 'Greys_r', 'OrRd_r', 'Oranges_r', 'PRGn_r', 'PiYG_r', 'PuBu_r', 'PuBuGn_r', 'PuOr_r', 'PuRd_r', 'Purples_r', 'RdBu_r', 'RdGy_r', 'RdPu_r', 'RdYlBu_r', 'RdYlGn_r', 'Reds_r', 'Spectral_r', 'Wistia_r', 'YlGn_r', 'YlGnBu_r', 'YlOrBr_r', 'YlOrRd_r', 'afmhot_r', 'autumn_r', 'binary_r', 'bone_r', 'brg_r', 'bwr_r', 'cool_r', 'coolwarm_r', 'copper_r', 'cubehelix_r', 'flag_r', 'gist_earth_r', 'gist_gray_r', 'gist_heat_r', 'gist_ncar_r', 'gist_rainbow_r', 'gist_stern_r', 'gist_yarg_r', 'gnuplot_r', 'gnuplot2_r', 'gray_r', 'hot_r', 'hsv_r', 'jet_r', 'nipy_spectral_r', 'ocean_r', 'pink_r', 'prism_r', 'rainbow_r', 'seismic_r', 'spring_r', 'summer_r', 'terrain_r', 'winter_r', 'Accent_r', 'Dark2_r', 'Paired_r', 'Pastel1_r', 'Pastel2_r', 'Set1_r', 'Set2_r', 'Set3_r', 'tab10_r', 'tab20_r', 'tab20b_r', 'tab20c_r', 'rocket', 'rocket_r', 'mako', 'mako_r', 'icefire', 'icefire_r', 'vlag', 'vlag_r', 'flare', 'flare_r', 'crest', 'crest_r']
